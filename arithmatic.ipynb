# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

#Load image and convert color domain
path1 = 'images/trex.png'
path2 = 'images/beach.png'
image1 = cv2.imread(path1)
image2 = cv2.imread(path2)

#Convert to other color spaces
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

#Create Numpy array with the same dimension as original image
M1 = np.ones(image1.shape, dtype='uint8')*100
M2 = np.ones(image1.shape, dtype='uint8')*120

#Image arithmatic operation
added = cv2.add(image1, M1)
subtracted = cv2.subtract(image1, M2)

#Plot image
fig = plt.figure(figsize=(20, 14))
ax1 = fig.add_subplot(1,3,1)
ax1.set(title='Original image')
ax1.imshow(image)
ax2 = fig.add_subplot(1,3,2)
ax2.set(title='Added')
ax2.imshow(added)
ax3 = fig.add_subplot(1,3,3)
ax3.set(title='Subtracted')
ax3.imshow(subtracted)

# %%
#Padding image1
replicate = cv2.copyMakeBorder(image1, 5, 0, 0, 0, cv2.BORDER_REPLICATE)

#Image arithmatic operation (between image)
added2 = cv2.add(replicate, image2)
subtracted2 = cv2.subtract(replicate, image2)
weight = cv2.addWeighted(replicate,0.7,image2,0.3,0)

#Plot image
fig = plt.figure(figsize=(20, 14))
ax1 = fig.add_subplot(1,3,1)
ax1.set(title='Added 2 images')
ax1.imshow(added2)
ax2 = fig.add_subplot(1,3,2)
ax2.set(title='Subtracted 2 images')
ax2.imshow(subtracted2)
ax3 = fig.add_subplot(1,3,3)
ax3.set(title='Weight added 2 images')
ax3.imshow(weight)
